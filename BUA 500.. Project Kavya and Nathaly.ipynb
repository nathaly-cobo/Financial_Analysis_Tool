# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset= ("G:/.shortcut-targets-by-id/1ppkxhk1_i1qkagib3HrczZa5MYHb9N5V/BUA 500 Project/forbes global 2022- companies.csv")

# %%
df= pd.read_csv(dataset)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(50)
# Out:
#     rank                            global company         country  \
# 0      1                        Berkshire Hathaway   United States
# 1      2                                      ICBC           China
# 2      3  Saudi Arabian Oil Company (Saudi Aramco)    Saudi Arabia
# 3      4                            JPMorgan Chase   United States
# 4      5                   China Construction Bank           China
# 5      6                                    Amazon   United States
# 6      7                                     Apple   United States
# 7      8                Agricultural Bank of China           China
# 8      9                           Bank of America   United States
# 9     10                              Toyota Motor           Japan
# 10    11                                  Alphabet   United States
# 11    12                                 Microsoft   United States
# 12    13                             Bank of China           China
# ...

# %%
df.plot(x="rank",y="sales_billions", color="red", linestyle="dashed", marker="o", markersize=2)
# Out:
# <AxesSubplot:xlabel='rank'>

# %%
df.plot(x="rank",y="profit_billions", color="black", linestyle="dashed", marker="o", markersize=2)
# Out:
# <AxesSubplot:xlabel='rank'>

# %%
df.plot(x="rank",y=["profit_billions","sales_billions","market value_billions"], color="black", linestyle="dashed", marker="o", markersize=2)
# Out:
# <AxesSubplot:xlabel='rank'>
